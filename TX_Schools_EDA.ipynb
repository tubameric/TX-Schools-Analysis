# %% [markdown]
# <a href="https://colab.research.google.com/github/tubameric/TX-Schools-Analysis/blob/main/TX_Schools_EDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Assigning the dataset URL
url='https://raw.githubusercontent.com/nvamsimohan/DallasDSA/main/2021%20Texas%20High%20Schools%20Scores.csv'

# Displaying the url
url
# Out:
# 'https://raw.githubusercontent.com/nvamsimohan/DallasDSA/main/2021%20Texas%20High%20Schools%20Scores.csv'

# %%
# Importing pandas for data processing
import pandas as pd

# %%
# Importing the data into a variable
data=pd.read_csv(url)

# Display the data
data
# Out:
#                                   School  \
# 0                       Lasa High School
# 1     School For The Talented And Gifted
# 2      School Of Science And Engineering
# 3             Health Careers High School
# 4            Debakey H S For Health Prof
# ...                                  ...
# 1816                 W B Bizzell Academy
# 1817                 Phoenix High School
# 1818     Graduation Prep Academy Navarro
# 1819                              Munday
# 1820                    La Feria Academy
#
#                                              School URL  \
# 0     https://www.schooldigger.com/go/TX/schools/089...
# 1     https://www.schooldigger.com/go/TX/schools/162...
# 2     https://www.schooldigger.com/go/TX/schools/162...
# 3     https://www.schooldigger.com/go/TX/schools/331...
# 4     https://www.schooldigger.com/go/TX/schools/236...
# ...                                                 ...
# 1816  https://www.schooldigger.com/go/TX/schools/321...
# ...

# %%
# Displaying the dataset shape
data.shape
# Out:
# (1821, 25)

# %%
# Displaying the dataset info
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1821 entries, 0 to 1820
# Data columns (total 25 columns):
#  #   Column                                                Non-Null Count  Dtype
# ---  ------                                                --------------  -----
#  0   School                                                1821 non-null   object
#  1   School URL                                            1821 non-null   object
#  2   District                                              1821 non-null   object
#  3   District URL                                          1821 non-null   object
#  4   City                                                  1821 non-null   object
#  5   City URL                                              1821 non-null   object
#  6   Zip                                                   1821 non-null   int64
#  7   County                                                1821 non-null   object
# ...

# %%
# Displaying descriptive stats of the dataset
data.describe()
# Out:
#                 Zip  Number Students  Number Full-time Teachers  \
# count   1821.000000      1821.000000                1811.000000
# mean   77315.758375       916.175728                  61.561016
# std     1437.680272       992.964357                  57.729077
# min    75002.000000         0.000000                   0.000000
# 25%    76063.000000       205.000000                  19.600000
# 50%    77358.000000       456.000000                  36.200000
# 75%    78570.000000      1476.000000                  96.350000
# max    79938.000000     10450.000000                 288.600000
#
#        Student/Teacher Ratio  Percent Free/Disc Lunch  Percent Homes Rented  \
# count            1810.000000              1821.000000           1821.000000
# mean               13.560939                59.395936             10.565678
# std                 4.968011                24.166854             13.997171
# min                 0.300000                 0.000000              0.000000
# ...

# %%
# Installing dataprep package for data profiling
# !pip install dataprep
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.9/9.9 MB 32.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.5/18.5 MB 34.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 133.6/133.6 kB 10.0 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 32.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 31.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 16.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 764.0/764.0 kB 10.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.4/6.4 MB 55.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.6/49.6 kB 4.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 61.7 MB/s eta 0:00:00
# ...

# %%
# Importing the dataprep package
from dataprep.eda import create_report

# %%
# Generating a data profiling report using dataprep's create_report
create_report(data).save()
# Out:
# Computing pow-b33424bc1873539db4646eeeed48b3f8:  20%|██        | 758/3724 [00:00<00:02, 1465.82it/s]             /usr/local/lib/python3.10/dist-packages/dask/core.py:121: RuntimeWarning: invalid value encountered in divide
#   return func(*(_execute_task(a, cache) for a in args))
# /usr/local/lib/python3.10/dist-packages/dataprep/eda/distribution/render.py:274: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.DataFrame({col: [nrows - npresent]}, index=["Others"]))
# /usr/local/lib/python3.10/dist-packages/dataprep/eda/distribution/render.py:274: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.DataFrame({col: [nrows - npresent]}, index=["Others"]))
# ...

# %%
# Displaying the data columns
data.columns
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-836591eeeab5> in <cell line: 2>()
#       1 # Displaying the data columns
# ----> 2 data.columns
#
# NameError: name 'data' is not defined

# %%
# Selecting variables with at least 80% available data
data80 = data[['School', 'School URL', 'District', 'District URL', 'City', 'City URL',
       'Zip', 'County', 'Phone', 'Is Title I', 'Is Charter', 'Is Magnet',
       'Is Virtual', 'Number Students', 'Number Full-time Teachers',
       'Student/Teacher Ratio', 'Percent Free/Disc Lunch',
       'Percent Homes Rented', 'Percent of Unemployment',
       'Percent Parents with Masters and above education',
       'Percent parents with less than High School education',
       'Percent Home Incomes with less than Median income',
      'Standard Score']]

# Displaying the data80 columns
data80.columns

# %%
# Displaying the data80 shape
data80.shape
# Out:
# (1821, 23)
# (1821, 23)

# %%
# Setting the predictor variables
predictors = data80[['District', 'City', 'Zip', 'County', 'Is Title I', 'Is Charter', 'Is Magnet',
       'Is Virtual', 'Number Students', 'Number Full-time Teachers',
       'Student/Teacher Ratio', 'Percent Free/Disc Lunch',
       'Percent Homes Rented', 'Percent of Unemployment',
       'Percent Parents with Masters and above education',
       'Percent parents with less than High School education',
       'Percent Home Incomes with less than Median income',
      'Standard Score']]

# Displaying predictor columns
predictors.columns
# Out:
# Index(['District', 'City', 'Zip', 'County', 'Is Title I', 'Is Charter',
#        'Is Magnet', 'Is Virtual', 'Number Students',
#        'Number Full-time Teachers', 'Student/Teacher Ratio',
#        'Percent Free/Disc Lunch', 'Percent Homes Rented',
#        'Percent of Unemployment',
#        'Percent Parents with Masters and above education',
#        'Percent parents with less than High School education',
#        'Percent Home Incomes with less than Median income', 'Standard Score'],
#       dtype='object')

# %%
# Displaying predictor data shape
predictors.shape
# Out:
# (1821, 18)

# %%
# Calculating correlations between variables
c1 = data[['Student/Teacher Ratio','Standard Score']]

# Displaying correlations
c1.corr()
# Out:
#                        Student/Teacher Ratio  Standard Score
# Student/Teacher Ratio               1.000000        0.031581
# Standard Score                      0.031581        1.000000

# %%
# Calculating correlations between variables
c2 = data[['Percent Parents with Masters and above education','Standard Score']]

# Displaying correlations
c2.corr()
# Out:
#                                                   Percent Parents with Masters and above education  \
# Percent Parents with Masters and above education                                          1.000000
# Standard Score                                                                            0.310479
#
#                                                   Standard Score
# Percent Parents with Masters and above education        0.310479
# Standard Score                                          1.000000

# %%
predictors.corr()
# Out:
# <ipython-input-19-760e4d21e4d4>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   predictors.corr()
#                                                          Zip  Number Students  \
# Zip                                                 1.000000        -0.058393
# Number Students                                    -0.058393         1.000000
# Number Full-time Teachers                          -0.056061         0.981253
# Student/Teacher Ratio                              -0.028711         0.354813
# Percent Free/Disc Lunch                             0.097709        -0.149198
# Percent Homes Rented                               -0.331629         0.125275
# Percent of Unemployment                            -0.123798        -0.022259
# Percent Parents with Masters and above education   -0.135305         0.312796
# ...
